# %%
import matplotlib.pyplot as plt

cKBS_parameters = ['10', '25', '50', '100']
cKBS_values = [2.20e-4, 2.29e-4, 3.16e-4, 3.92e-4]

FRN_parameters = ['10', '25', '50', '100']
FRN_values = [1.45e-3, 2.78e-3, 7.17e-3, 9.44e-2]

plt.figure(figsize=(6, 5), dpi= 300)
plt.plot(cKBS_parameters, cKBS_values, marker='s', label='LCDA')
plt.plot(FRN_parameters, FRN_values, marker='o', label='FRN')
plt.xlabel('Size of facts')
plt.ticklabel_format(axis='y', style='sci', scilimits=(2,4))
plt.grid(visible= True, linestyle = '--')
plt.ylabel('Execution Time')
#plt.title('Comparison of Methods')
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt

cKBS_parameters = ['10', '25', '50', '100']
cKBS_values = [2.3e-4, 3.1e-4, 3.5e-4, 6.7e-4]
# cKBS_rules = [0.005, 10, 15, 20]  # Number of rules for cKBS

FRN_paramet = ['10', '25', '50', '100']
FRN_values = [1.4e-3, 2.7e-3, 7.1e-3, 9.4e-3]

# FRN_rules = [7, 12, 18, 25]  # Number of rules for FRN

plt.figure(figsize=(6, 5), dpi=300)

# Plot execution time
plt.plot(cKBS_parameters, cKBS_values, marker='s', label='LCDA')
plt.plot(FRN_parameters, FRN_values, marker='o', label='FRN')

# # Plot number of rules
# plt.plot(cKBS_parameters, cKBS_rules, marker='s', label='cKBS Rules')
# plt.plot(FRN_parameters, FRN_rules, marker='d', label='FRN Rules')

plt.xlabel('Size of facts')
plt.ylabel('Execution Time / Number of Rules')

plt.ticklabel_format(axis='y', style='sci', scilimits=(2, 4))
plt.grid(visible=True, linestyle='--')

plt.legend()
plt.show()

# %%
import numpy as np
from matplotlib import pyplot as plt

# Set the figure size
plt.rcParams["figure.figsize"] = [7.50, 3.50]
plt.rcParams["figure.autolayout"] = True

# x and y data points
x = np.linspace(1, 100, 1000)
y = np.log(x)

plt.figure(figsize=(6, 5), dpi=300)
# logarithmic scale
plt.yscale('log')

# Plot the x and y data points
plt.plot(x, y, c="red", lw=3, linestyle="dashdot", label="y=log(x)")

# Place the legend
plt.legend()

# Display the plot
plt.show()

# %%
import matplotlib.pyplot as plt

number_of_facts = ['50', '100' ,'1000','10000', '25000', '50000', '100000']
# cKBS_values = [1.56e-2, 1.11e-1, 4.21e-1, 8.89e-1, 1.73]
# Parallel_values = [3.01e-4, 3.38e-4, 3.385e-4, 3.42e-4, 4.71e-4]
LCDA_values_AD = [1.07e-4, 1.70e-4, 9.9e-3, 9.05e-2, 2.38e-1, 5.52e-1, 1.53]
LCDA_values_UnAuth = [4.41e-4, 6.13e-4, 1.19e-3, 1.81e-3, 3.26e-2, 8.67e-2, 1.09e-1]
LCDA_values_InDec = [1.52e-4, 9.87e-4, 8.8e-3, 5.67e-2, 1.49e-1, 3.07e-1, 6.44e-1]
plt.figure(figsize=(8, 6), dpi=200)
plt.plot(number_of_facts, LCDA_values_InDec, marker='o',label='Intrusion Detection')
plt.plot(number_of_facts, LCDA_values_AD, marker='o',label='Anomaly Detection')
plt.plot(number_of_facts, LCDA_values_UnAuth, marker='o', label='Unauthorized Access')


plt.yscale('log')

plt.xlabel('Number of facts')
plt.ylabel('Execution Time (sec)')
# plt.title('Comparision of Execution Times of Parallel-LCDA and LCDA for Anomaly Detection Case')

plt.legend()
# plt.grid(visible= True, linestyle = '--')

plt.show()

# %%
import matplotlib.pyplot as plt

number_of_facts = ['50', '100' ,'1000','10000', '25000', '50000', '100000']
# cKBS_values = [1.56e-2, 1.11e-1, 4.21e-1, 8.89e-1, 1.73]
# Parallel_values = [3.01e-4, 3.38e-4, 3.385e-4, 3.42e-4, 4.71e-4]
PLCDA_values_AD = [3.1e-4, 2.64e-4, 3.13e-4, 2.35e-4, 2.30e-4, 2.73e-4, 2.32e-4]
PLCDA_values_UnAuth = [5.2e-5, 4.37e-5, 4.81e-5, 4.62e-5, 4.49e-5, 3.36e-5, 4.96e-5]
PLCDA_values_InDec = [2.40e-4, 3.77e-4, 2.31e-4, 2.12e-4, 3.85e-4, 1.785e-4, 2.78e-4]
plt.figure(figsize=(8, 6), dpi=200)
plt.plot(number_of_facts, PLCDA_values_InDec, marker='o',label='Intrusion Detection')
plt.plot(number_of_facts, PLCDA_values_AD, marker='o',label='Anomaly Detection')
plt.plot(number_of_facts, PLCDA_values_UnAuth, marker='o', label='Unauthorized Access')


plt.yscale('log')

plt.xlabel('Number of facts')
plt.ylabel('Execution Time (sec)')
# plt.title('Comparision of Execution Times of Parallel-LCDA and LCDA for Anomaly Detection Case')

plt.legend()
plt.grid(visible= True, linestyle = '--')

plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

number_of_facts = ['50', '100', '1000', '10000', '25000', '50000', '100000']
LCDA_values_AD = [1.07e-4, 1.70e-4, 9.9e-3, 9.05e-2, 2.38e-1, 5.52e-1, 1.53]
LCDA_values_UnAuth = [4.41e-4, 6.13e-4, 1.81e-3, 1.19e-2, 3.26e-2, 8.67e-2, 1.09e-1]
LCDA_values_InDec = [1.52e-4, 9.87e-4, 8.8e-3, 5.67e-2, 1.49e-1, 3.07e-1, 6.44e-1]

plt.figure(figsize=(8, 6), dpi=200)

sns.lineplot(x=number_of_facts, y=LCDA_values_InDec, marker='o', label='Intrusion Detection')
sns.lineplot(x=number_of_facts, y=LCDA_values_AD, marker='o', label='Anomaly Detection')
sns.lineplot(x=number_of_facts, y=LCDA_values_UnAuth, marker='o', label='Unauthorized Access')

plt.yscale('log')

# plt.xlabel('Number of Facts')
# plt.ylabel('Execution Time (sec)')
# plt.title('Comparison of Execution Times')
# plt.legend()
# plt.grid(visible=True, linestyle='--')

# plt.show()

# %%
tips = sns.load_dataset("tips")
g = sns.FacetGrid(tips, col="time")

# %%
attend = sns.load_dataset("attention").query("subject <= 12")
g = sns.FacetGrid(attend, col="subject", col_wrap=4, height=2, ylim=(0, 10))
g.map(sns.pointplot, "solutions", "score", order=[1, 2, 3], color=".3", errorbar=None)
# Out:
# c:\Users\KHAN\Downloads\ContextBasedAD\test\Lib\site-packages\seaborn\axisgrid.py:123: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\KHAN\Downloads\ContextBasedAD\LCDA jupyter\finalGraphs.ipynb Cell 10 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/KHAN/Downloads/ContextBasedAD/LCDA%20jupyter/finalGraphs.ipynb#X12sZmlsZQ%3D%3D?line=0'>1</a> usd = df[df['Currency']=='US dollar'].reset_index(drop=True)
#       <a href='vscode-notebook-cell:/c%3A/Users/KHAN/Downloads/ContextBasedAD/LCDA%20jupyter/finalGraphs.ipynb#X12sZmlsZQ%3D%3D?line=1'>2</a> sns.lineplot(x='Date', y='Euro rate', data=usd)
#
# NameError: name 'df' is not defined
